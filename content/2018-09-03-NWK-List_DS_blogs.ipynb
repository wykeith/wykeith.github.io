# %% [markdown]
# # Data Science Blogs
# ![I never trust anyone who's more excited about success than about doing the thing they want to be successful at.][xkcd]
#
# A curated list of data science notebooks to explore before the one year sprint begins =/
# Machine Learning Notebooks
# ==========================
#
# Tips & Tutorials
# ----------------
#
# *   A collection of not so obvious Python stuff you should know! \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/not_so_obvious_python_stuff.ipynb)\]
# *   Python’s scope resolution for variable names and the LEGB rule \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/scope_resolution_legb_rule.ipynb)\]
# *   Key differences between Python 2.x and Python 3.x \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/key_differences_between_python_2_and_3.ipynb)\]
# *   A collection of useful regular expressions \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/useful_regex.ipynb)\]
# *   A random collection of useful Python snippets \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/python_patterns/patterns.ipynb)\]
#
# Statistics
# ----------
#
# *   Exploratory Data Analysis \[[Jupyter Notebook](https://github.com/rasbt/data-science-tutorial/blob/master/code/eda.ipynb)\]
# *   Summary Statistics \[[Jupyter Notebook](https://github.com/rasbt/data-science-tutorial/blob/master/code/summary-stats.ipynb)\]
# *   Covariance and Correlation \[[Jupyter Notebook](https://github.com/rasbt/data-science-tutorial/blob/master/code/cov-corr.ipynb)\]
# *   Probability Mass Functions \[[Jupyter Notebook](https://github.com/rasbt/data-science-tutorial/blob/master/code/pmf_1.ipynb)\]
# *   Probability Density Functions \[[Jupyter Notebook](https://github.com/rasbt/data-science-tutorial/blob/master/code/pdf_1.ipynb)\]
# *   Least-Squares Linear Regression \[[Jupyter Notebook](https://github.com/rasbt/data-science-tutorial/blob/master/code/linear-reqression-leastsquares.ipynb)\]
# *   Bootstrapping (Nonparametric Inference) \[[Jupyter Notebook](https://github.com/rasbt/data-science-tutorial/blob/master/code/bootstrapping.ipynb)\]
# *   Hypothesis Testing Introduction \[\[Jupyter Notebook\](https://github.com/rasbt/data-science-tutorial/blob/master/
# *   code/hypothesis-testing\_1.ipynb)\]
#
# Scientific Computing
# --------------------
#
# *   Sorting CSV files using the Python csv module \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/sorting_csvs.ipynb)\]
# *   Using Cython with and without IPython magic \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/running_cython.ipynb)\]
# *   Parallel processing via the multiprocessing module \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/multiprocessing_intro.ipynb)\]
# *   Entry point: Data - using sci-packages to prepare data for Machine Learning tasks and other data analyses \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/python_data_entry_point.ipynb)\]
# *   Quick guide for dealing with missing numbers in NumPy \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/numpy_nan_quickguide.ipynb)\]
# *   Converting large CSV files to SQLite databases using pandas \[[Jupyter Notebook](https://github.com/rasbt/python_reference/blob/master/useful_scripts/large_csv_to_sqlite.py)\]
# *   Sparsifying a matrix by zeroing out all elements but the top k elements in a row using NumPy \[[Jupyter Notebook](https://github.com/rasbt/python_reference/blob/master/useful_scripts/sparsify_matrix.py)\]
# *   Things in pandas I wish I’d had known earlier \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/things_in_pandas.ipynb)\]
#
# Math & Algorithms
# -----------------
#
# *   Sorting Algorithms \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/sorting/sorting_algorithms.ipynb)\]
# *   Linear regression via the least squares fit method \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/statistics/linregr_least_squares_fit.ipynb)\]
# *   Dixon’s Q test to identify outliers for small sample sizes \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/statistics/dixon_q_test.ipynb)\]
# *   Rejection sampling \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/statistics/rejection_sampling.ipynb)\]
# *   Counting points inside a hypercube \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/geometry/points_in_hybercube.ipynb)\]
# *   Vectorizing a classic for-loop in NumPy for calculating Euclidean distances \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/geometry/eucldist_numpy_vectorization.ipynb)\]
# *   Maximum Pairwise Product \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/efficiency/maximum-pairwise-product.ipynb)\]
# *   Fibonacci Numbers \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/efficiency/fibonacci-tree.ipynb)\]
# *   Greatest Common Divisor \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/efficiency/greatest-common-divisor.ipynb) \]
# *   Introduction to Greedy Algorithms \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/essentials/greedy-algorithm-intro.ipynb)\]
# *   Introduction to Divide-and-Conquer Algorithms \[ [Jupyter Notebookviewer](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/essentials/divide-and-conquer-algorithm-intro.ipynb) \]
#
# Data Structures
# ---------------
#
# *   Singly Linked List \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/algorithms_in_ipython_notebooks/blob/master/ipython_nbs/data-structures/singly-linked-list.ipynb)\]
#
# Web
# ---
#
# *   Creating internal links in IPython Notebooks and Markdown docs \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/table_of_contents_ipython.ipynb)\]
# *   A Simple Barebones Flask Webapp Template \[[GitHub Dir](https://github.com/rasbt/python-machine-learning-book/tree/master/code/bonus/flask_webapp_ex01)\]
#
# Benchmarks
# ----------
#
# *   Reversing strings \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day1_string_reverse.ipynb)\]
# *   Calculating sample means \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day2_mean_values.ipynb)\]
# *   6 different ways to count elements using a dict \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day3_dictionary_counting.ipynb)\]
# *   Python vs. Cython vs. Numba \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day4_python_cython_numba.ipynb)\]
# *   (C)Python compilers - Cython vs. Numba vs. Parakeet \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day4_2_cython_numba_parakeet.ipynb)\]
# *   Comparing 9 ways for flattening lists of sublists \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day5_flattening_lists.ipynb)\]
# *   Determining if a string is a number \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day6_string_is_number.ipynb)\]
# *   Speeding up NumPy array expressions with Numexpr \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day7_numpy_numexpr.ipynb)\]
# *   Just-in-time compilers for NumPy array expressions \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day7_2_jit_numpy.ipynb)\]
# *   Calculating square roots and exponents \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day8_sqrt_and_exp.ipynb)\]
# *   The most Pythonic way to check if a string ends with a particular substring \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/mastr/ipython_nbs/day9_string_endswith.ipynb)\]
# *   Cython - Bridging the gap between Python and Fortran \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day10_fortran_lstsqr.ipynb)\]
# *   The `deque` container data type [Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day11_deque_container.ipynb)\]
# *   Lightning fast insertion into sorted lists via the `bisect` module \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day12_insert_into_sorted_list.ipynb)\]
# *   Parallel processing via the multiprocessing module \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/tutorials/multiprocessing_intro.ipynb)\]
# *   Python’s and NumPy’s in-place operator functions \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day14_inplace_operators.ipynb)\]
# *   Array indexing in NumPy: Extracting rows and columns \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day15_array_indexing_numpy.ipynb)\]
# *   Vectorizing a classic for-loop in NumPy \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day16_numpy_vectorization.ipynb)\]
# *   Stacking NumPy arrays \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day17_numpy_stacking.ipynb)\]
# *   The scikit-learn preprocessing module for feature scaling \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day18_sckit_preprocessing.ipynb)\]
# *   Python 2.7.x’s `izip` and `xrange` \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day19_izip_and_xrange.ipynb)\]
# *   Calculating the difference between successive elements in a Python list \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/One-Python-benchmark-per-day/blob/master/ipython_nbs/day20_difference_list.ipynb)\]
#
# Matplotlib
# ----------
#
# *   2D histograms / heat maps / levelplots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/heatmaps.ipynb)\]
# *   3D Plots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/3dplots.ipynb)\]
# *   Bar plots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/barplots.ipynb)\]
# *   Boxplots and Violinplots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/boxplots.ipynb)\]
# *   Errorbar plots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/errorbars.ipynb)\]
# *   Formatting I: subplots, markers, colors, axes \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/formatting_1.ipynb)\]
# *   Formatting II: gridlines \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/formatting_2.ipynb)\]
# *   Formatting III: What it takes to become a legend \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/formatting_3.ipynb)\]
# *   Histograms \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/histograms.ipynb)\]
# *   Line plots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/lineplots.ipynb)\]
# *   Preparing Plots for Publication \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/publication.ipynb)\]
# *   Scatter plots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/scatterplots.ipynb)\]
# *   Special plots \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/specialplots.ipynb)\]
# *   Clustering - Heatmaps and Dendrograms \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/clust_complete_linkage.ipynb)\]
# *   Tips and Tricks \[[Jupyter Notebook](http://nbviewer.ipython.org/github/rasbt/matplotlib-gallery/blob/master/ipynb/tricks.ipynb)\]
# [xkcd]: https://imgs.xkcd.com/comics/time_management.png "I never trust anyone who's more excited about success than about doing the thing they want to be successful at."
